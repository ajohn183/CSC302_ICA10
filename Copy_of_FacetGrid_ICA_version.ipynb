# %% [markdown]
# <a href="https://colab.research.google.com/github/ajohn183/CSC302_ICA10/blob/main/Copy_of_FacetGrid_ICA_version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# *   Please read titanic.csv from the DATA folder
# *   Change 1s to "Survived" under the Survived column of the data frame by looking at the example provided.
# *   Get rows which don't have "?" under Pclass column and move to the next step.

# %%
titanic = pd.read_csv('/content/drive/MyDrive/DATA/titanic.csv')
df= titanic.copy()
df['Survived'] = df['Survived'].replace(1, 'Survived')
df_filter=df[df['Pclass']!='?']
pd.set_option('display.max_rows', None)
print(df_filter)
# Out:
#      Unnamed: 0  PassengerId  Survived Pclass  \
# 0             0            1         0      3
# 1             1            2  Survived      1
# 2             2            3  Survived      3
# 3             3            4  Survived      1
# 4             4            5         0      3
# 5             5            6         0      3
# 6             6            7         0      1
# 7             7            8         0      3
# 8             8            9  Survived      3
# 9             9           10  Survived      2
# 10           10           11  Survived      3
# 11           11           12  Survived      1
# 12           12           13         0      3
# 13           13           14         0      3
# 14           14           15         0      3
# 15           15           16  Survived      2
# 16           16           17         0      3
# 17           17           18  Survived      2
# 18           18           19         0      3
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Create a multipanel plot which draws density plots for each class-survived combination. Please also use the hue parameter based on the Sex attribute to have two density plots in each panel with different colors.

# %%
titanic = pd.read_csv('/content/drive/MyDrive/DATA/titanic.csv')
df= titanic.copy()
df['Survived'] = df['Survived'].replace({1: 'Survived', 0: 'Died'})
df= df[df["Age"].notna()]
df_filter=df[df['Pclass']!='?']
df_filter.loc[:, 'Pclass'] = df_filter['Pclass'].astype(str)
g = sns.FacetGrid(df_filter, row="Pclass", col="Survived", margin_titles=True, hue="Sex",sharex=True, sharey=True )
g.map_dataframe(sns.kdeplot,"Age", fill=True)

#you can uncomment below when you come up with your density plots for each class-survived combination
titles = ['Died in Class 3','Died in Class 1', 'Died in Class 2', 'Survived in Class 3','Survived in Class 1', 'Survived in Class 2']
for ax,title in zip(g.axes.flatten(),titles):
   ax.set_title(title )
g.set_axis_labels("Age", "Density")
g.add_legend()

plt.show()
